# %%
import math
import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from sklearn.model_selection import train_test_split

from config import *
from nerf import *
from camera_operations import *
from dataset import *
# Out:
# using device: cuda
# Train Images Shape: (100, 100, 100, 3)
# Train Poses Shape: (100, 4, 4)
# Validation Image Shape: (100, 100, 3)
# Validation Pose Shape: (4, 4)
# Images shape: (106, 100, 100, 3)
# Poses shape: (106, 4, 4)
# Focal value: 138.88888
# x-fov: 39.597755335771296
# y-fov: 39.597755335771296

# %%
show_dataset()

# %%
# load the coarse model from file
coarse_sampler = CoarseNeRFSampler(t_min=0, t_max=8, Nc=64) 
coarse_model = NeRF(hidden_dim=128, sampler=coarse_sampler, name="coarse_128").to(device = device ,dtype=dtype)
coarse_model.load_state_dict(torch.load("models/model_coarse_128_35.pt"))
coarse_model.eval()
fine_sampler = FineNeRFSampler(coarse_model, Nf=128, Nc=64, t_min=0, t_max=8)
fine_model = NeRF(sampler=fine_sampler, Nc=128).to(device = device ,dtype=dtype)

# %%
u, v = torch.meshgrid(torch.linspace(-image_height/2, image_width/2, image_height), torch.linspace(-image_width/2, image_width/2, image_width))
ds = extract_origin_and_direction(torch.Tensor(train_poses).to(device), u, v)[:,:,0,3:]
i = np.random.randint(0, train_poses.shape[0])

# 3D plot of the camera positions
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
# ax.scatter(train_poses[:, 0, 3].cpu(), train_poses[:, 1, 3].cpu(), train_poses[:, 2, 3].cpu())
# for i in range(0, train_poses.shape[0]):
#     ax.quiver(train_poses[i, 0, 3].cpu(), train_poses[i, 1, 3].cpu(), train_poses[i, 2, 3].cpu(), -train_poses[i, 0, 2].cpu(), -train_poses[i, 1, 2].cpu(), -train_poses[i, 2, 2].cpu(), length=0.5, normalize=True, color='r')

# we now plot only the first camera pose, in yellow
ax.scatter(train_poses[0, 0, 3].cpu(), train_poses[0, 1, 3].cpu(), train_poses[0, 2, 3].cpu(), color='y')
ax.quiver(train_poses[0, 0, 3].cpu(), train_poses[0, 1, 3].cpu(), train_poses[0, 2, 3].cpu(), -train_poses[0, 0, 2].cpu(), -train_poses[0, 1, 2].cpu(), -train_poses[0, 2, 2].cpu(), length=0.5, normalize=True, color='y')


# black box at the origin for reference, length 1
ax.quiver(0, 0, 0, 0, 0, 1, length=1, normalize=True, color='k')

# for first camera pose, plot the image plane
# 4 corners of the image plane
dc = image_width / (2 * f)

corners = torch.tensor([[-dc, -dc, 0, 1], [-dc, dc, -0, 1], [dc, dc, -0, 1], [dc, -dc, -0, 1]], device = device, dtype = dtype)
corners = train_poses[0] @ corners.t()
corners = corners[:3] / corners[3]
corners = corners.t().cpu().numpy()
# connect the corners
ax.plot([corners[0, 0], corners[1, 0]], [corners[0, 1], corners[1, 1]], [corners[0, 2], corners[1, 2]], color='b')
ax.plot([corners[1, 0], corners[3, 0]], [corners[1, 1], corners[3, 1]], [corners[1, 2], corners[3, 2]], color='b')
ax.plot([corners[3, 0], corners[2, 0]], [corners[3, 1], corners[2, 1]], [corners[3, 2], corners[2, 2]], color='b')
ax.plot([corners[2, 0], corners[0, 0]], [corners[2, 1], corners[0, 1]], [corners[2, 2], corners[0, 2]], color='b')

# quiver plot of the pixel rays
for i in range(0, image_height, 10):
    for j in range(0, image_width, 10):
        ax.quiver(train_poses[0, 0, 3].cpu(), train_poses[0, 1, 3].cpu(), train_poses[0, 2, 3].cpu(), ds[i, j, 0].cpu(), ds[i, j, 1].cpu(), ds[i, j, 2].cpu(), length=0.5, normalize=True, color='g')

# plot a sample pixel ray
sampler = FineNeRFSampler(model=coarse_model, t_max=8)
ts = sampler.sample(train_poses[0, :3, 3], ds[50, 50])
print(ts.shape)
xs = train_poses[0, :3, 3].cpu() + ds[50, 50].cpu() * ts[:, None].cpu()
xs = xs.detach().cpu().numpy()
ax.scatter(xs[:, 0], xs[:, 1], xs[:, 2], color='r')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
# Out:
# c:\Users\Mathis\.conda\envs\ProjetTunnel\lib\site-packages\torch\functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:3550.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 u, v = torch.meshgrid(torch.linspace(-image_height/2, image_width/2, image_height), torch.linspace(-image_width/2, image_width/2, image_width))
# ----> 2 ds = extract_origin_and_direction(torch.Tensor(train_poses).to(device), u, v)[:,:,0,3:]
#       3 i = np.random.randint(0, train_poses.shape[0])
#       5 # 3D plot of the camera positions
#
# TypeError: extract_origin_and_direction() missing 1 required positional argument: 'camera_intrinsics'

# %%
fine_model.train_model(train_poses, train_images)
# Out:
# Preprocessing ...
# Training the model ...
# C:\Users\Mathis\AppData\Local\Temp\ipykernel_1372\3525372724.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   u = torch.tensor(u, device = device, dtype = dtype)
# C:\Users\Mathis\AppData\Local\Temp\ipykernel_1372\3525372724.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   v = torch.tensor(v, device = device, dtype = dtype)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 4
#       2 fine_model = NeRF(sampler=fine_sampler).to(device = device ,dtype=dtype)
#       3 fine_model.Nc = 128
# ----> 4 fine_model.train_model(train_poses, train_images)
#
# Cell In[8], line 259, in NeRF.train_model(***failed resolving arguments***)
#     256 o = od[:, :3]
#     257 d = od[:, 3:]
# --> 259 pred_rgb = self.sample_and_get_ray_color(o, d)
#     261 loss = F.mse_loss(pred_rgb, target_rgb)
#     262 loss = torch.mean((torch.log1p(pred_rgb) - torch.log1p(target_rgb)) ** 2)
#
# Cell In[8], line 165, in NeRF.sample_and_get_ray_color(self, o, d)
#     160 """
#     161 @param o: Tensor of shape (n_rays, 3)
#     162 @param d: Tensor of shape (n_rays, 3)
#     163 """
#     164 t = self.sampler.sample(o, d)
# --> 165 return self.get_colors_from_ray(o, d, t)
#
# Cell In[8], line 144, in NeRF.get_colors_from_ray(self, o, d, t)
#     137 """
#     138 @param o: Tensor of shape (n_rays, 3)
#     139 @param d: Tensor of shape (n_rays, 3)
#     140 @param t: Tensor of shape (n_rays, Nc + 1)
#     141 @return ray_colors: Tensor of shape (n_rays, 3)
#     142 """
#     143 x = o[:, None, :] + d[:, None, :] * t[:, :-1, None] # shape: [n_rays, Nc, 3]
# --> 144 ouputs = self.encod_forward(x, d) # shape: [n_rays, Nc, 3]
#     145 ray_colors = self.output_to_color(ouputs, t)
#     146 return ray_colors
#
# Cell In[8], line 113, in NeRF.encod_forward(self, x, d)
#     110 encoded_x = self.positional_encoding(x/8, self.Lx)
#     111 encoded_d = self.positional_encoding(d, self.Ld)
# --> 113 outputs = self(encoded_x, encoded_d)
#     114 outputs = outputs.reshape(n_rays, self.Nc, 4)
#     116 return outputs
#
# File c:\Users\Mathis\.conda\envs\ProjetTunnel\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Mathis\.conda\envs\ProjetTunnel\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[8], line 90, in NeRF.forward(self, x, d)
#      87 # Next 4 layers of the network => Outputs sigma values for the Nc samples
#      88 # Then we concatenate the output with gamma(d)
#      89 x_branch2 = self.branch2(concatenated_input)
# ---> 90 concatenated_input = torch.cat((x_branch2[:, 1:], d), dim=1) # We remove the first element of x_branch2 because it is the sigma value
#      92 sigma = x_branch2[:, :1]               # Sigma values
#      93 rgb = self.branch3(concatenated_input) # RGB values
#
# RuntimeError: Sizes of tensors must match except in dimension 1. Expected size 635000 but got size 640000 for tensor number 1 in the list.

# %%
# try to reconstruct the image from the validation pose
fine_model.eval()
i = np.random.randint(0, len(train_poses))
predicted_image = fine_model.predict_scene(train_poses[i])
predicted_image = predicted_image.detach().cpu().numpy()
predicted_image = predicted_image / np.max(predicted_image)
predicted_image = predicted_image
plt.figure(figsize=(16, 8))
plt.subplot(1, 2, 1)
plt.imshow(predicted_image)
plt.title("Predicted Image")

plt.subplot(1, 2, 2)
plt.imshow(train_images[i].cpu().numpy())
plt.title("Ground Truth Image")
plt.suptitle("Coarse Model Prediction, i = " + str(i))
plt.show()
# Out:
# C:\Users\Mathis\AppData\Local\Temp\ipykernel_24480\3525372724.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   u = torch.tensor(u, device = device, dtype = dtype)
# C:\Users\Mathis\AppData\Local\Temp\ipykernel_24480\3525372724.py:17: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   v = torch.tensor(v, device = device, dtype = dtype)
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[133], line 4
#       2 coarse_model.eval()
#       3 i = np.random.randint(0, len(train_poses))
# ----> 4 predicted_image = coarse_model.predict_scene(train_poses[i])
#       5 predicted_image = predicted_image.detach().cpu().numpy()
#       6 predicted_image = predicted_image / np.max(predicted_image)
#
# Cell In[15], line 213, in NeRF.predict_scene(self, pose)
#     211 def predict_scene(self, pose):
#     212     pose = torch.as_tensor(pose, device=device, dtype=dtype)
# --> 213     return self.predict_scenes(pose.unsqueeze(0))[0]
#
# Cell In[15], line 204, in NeRF.predict_scenes(self, poses)
#     201 for i in range(0, n_rays, self.batch_size):
#     202     os, ds = o[i:i+self.batch_size], d[i:i+self.batch_size]
#     203     rgb_colors.append(
# --> 204         self.sample_and_get_ray_color(os, ds)
#     205     )
#     206 rgb_colors = torch.cat(rgb_colors, dim=0)
#     208 rgb_colors = rgb_colors.reshape(B, image_height, image_width, 3)
#
# Cell In[15], line 166, in NeRF.sample_and_get_ray_color(self, o, d)
#     161 """
#     162 @param o: Tensor of shape (n_rays, 3)
#     163 @param d: Tensor of shape (n_rays, 3)
#     164 """
#     165 t = self.sampler.sample(o, d)
# --> 166 return self.get_colors_from_ray(o, d, t)
#
# Cell In[15], line 145, in NeRF.get_colors_from_ray(self, o, d, t)
#     138 """
#     139 @param o: Tensor of shape (n_rays, 3)
#     140 @param d: Tensor of shape (n_rays, 3)
#     141 @param t: Tensor of shape (n_rays, Nc + 1)
#     142 @return ray_colors: Tensor of shape (n_rays, 3)
#     143 """
#     144 x = o[:, None, :] + d[:, None, :] * t[:, :-1, None] # shape: [n_rays, Nc, 3]
# --> 145 ouputs = self.encod_forward(x, d) # shape: [n_rays, Nc, 3]
#     146 ray_colors = self.output_to_color(ouputs, t)
#     147 return ray_colors
#
# Cell In[15], line 114, in NeRF.encod_forward(self, x, d)
#     111 encoded_x = self.positional_encoding(x/8, self.Lx)
#     112 encoded_d = self.positional_encoding(d, self.Ld)
# --> 114 outputs = self(encoded_x, encoded_d)
#     115 outputs = outputs.reshape(n_rays, self.Nc, 4)
#     117 return outputs
#
# File c:\Users\Mathis\.conda\envs\ProjetTunnel\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Mathis\.conda\envs\ProjetTunnel\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[15], line 85, in NeRF.forward(self, x, d)
#      79 """
#      80 Forward pass of the network
#      81 @param x: Tensor of shape (n, 6 * Lx) containing the encoded x values of the sampled points
#      82 @param d: Tensor of shape (n, 6 * Ld) containing the encoded d values of the sampled points
#      83 """
#      84 # First 5 layers of the network => Then we concatenate the output with gamma(x) as in figure 7 of the paper
# ---> 85 x_branch1 = self.branch1(x)
#      86 concatenated_input = torch.cat((x_branch1, x), dim=1)
#      88 # Next 4 layers of the network => Outputs sigma values for the Nc samples
#      89 # Then we concatenate the output with gamma(d)
#
# File c:\Users\Mathis\.conda\envs\ProjetTunnel\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Mathis\.conda\envs\ProjetTunnel\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Mathis\.conda\envs\ProjetTunnel\lib\site-packages\torch\nn\modules\container.py:217, in Sequential.forward(self, input)
#     215 def forward(self, input):
#     216     for module in self:
# --> 217         input = module(input)
#     218     return input
#
# File c:\Users\Mathis\.conda\envs\ProjetTunnel\lib\site-packages\torch\nn\modules\module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Mathis\.conda\envs\ProjetTunnel\lib\site-packages\torch\nn\modules\module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File c:\Users\Mathis\.conda\envs\ProjetTunnel\lib\site-packages\torch\nn\modules\linear.py:116, in Linear.forward(self, input)
#     115 def forward(self, input: Tensor) -> Tensor:
# --> 116     return F.linear(input, self.weight, self.bias)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 314.00 MiB. GPU 0 has a total capacity of 4.00 GiB of which 0 bytes is free. Of the allocated memory 9.93 GiB is allocated by PyTorch, and 364.59 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
